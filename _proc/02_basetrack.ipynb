# %% [raw]
# ---
# description: A base track class to extend.
# output-file: basetrack.html
# title: basetrack
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(TrackState)
# Out:
# ---
#
# [source](https://github.com/cj-mills/cjm-byte-track/blob/main/cjm_byte_track/basetrack.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### TrackState
#
# >      TrackState (value, names=None, module=None, qualname=None, type=None,
# >                  start=1)
#
# Enum class to represent the possible states of a track.
#
# Attributes:
#
# - New: The initial state of the track when it's just detected.
# - Tracked: The state when the track is being actively tracked.
# - Lost: The state when the track is lost or not detected in the current frame.
# - Removed: The state when the track is removed from the tracking system.

# %%
#| echo: false
#| output: asis
show_doc(BaseTrack)
# Out:
# ---
#
# [source](https://github.com/cj-mills/cjm-byte-track/blob/main/cjm_byte_track/basetrack.py#L29){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseTrack
#
# >      BaseTrack ()
#
# Base class for a track in a tracking system.
#
# This class provides the basic functionalities and properties for a track,
# such as its unique ID, state, history, features, and related functions.
# Derived classes should implement the activate, predict, and update methods.
#
# Attributes:
#
# - `_count` (int): Class-level counter to generate unique IDs for tracks.

# %%
#| echo: false
#| output: asis
show_doc(BaseTrack.end_frame)
# Out:
# ---
#
# [source](https://github.com/cj-mills/cjm-byte-track/blob/main/cjm_byte_track/basetrack.py#L63){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseTrack.end_frame
#
# >      BaseTrack.end_frame ()
#
# Returns the current frame number as the end frame of the track.

# %%
#| echo: false
#| output: asis
show_doc(BaseTrack.next_id)
# Out:
# ---
#
# [source](https://github.com/cj-mills/cjm-byte-track/blob/main/cjm_byte_track/basetrack.py#L71){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseTrack.next_id
#
# >      BaseTrack.next_id ()
#
# Generates and returns the next unique track ID.

# %%
#| echo: false
#| output: asis
show_doc(BaseTrack.activate)
# Out:
# ---
#
# [source](https://github.com/cj-mills/cjm-byte-track/blob/main/cjm_byte_track/basetrack.py#L78){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseTrack.activate
#
# >      BaseTrack.activate (*args)
#
# Activates the track. This method should be implemented by derived classes.
#
# Raises:
# NotImplementedError: If the method is not implemented by derived classes.

# %%
#| echo: false
#| output: asis
show_doc(BaseTrack.predict)
# Out:
# ---
#
# [source](https://github.com/cj-mills/cjm-byte-track/blob/main/cjm_byte_track/basetrack.py#L87){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseTrack.predict
#
# >      BaseTrack.predict ()
#
# Predicts the next state of the track. This method should be implemented by derived classes.
#
# Raises:
# NotImplementedError: If the method is not implemented by derived classes.

# %%
#| echo: false
#| output: asis
show_doc(BaseTrack.update)
# Out:
# ---
#
# [source](https://github.com/cj-mills/cjm-byte-track/blob/main/cjm_byte_track/basetrack.py#L96){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseTrack.update
#
# >      BaseTrack.update (*args, **kwargs)
#
# Updates the state of the track based on new observations.
# This method should be implemented by derived classes.
#
# Raises:
# NotImplementedError: If the method is not implemented by derived classes.

# %%
#| echo: false
#| output: asis
show_doc(BaseTrack.mark_lost)
# Out:
# ---
#
# [source](https://github.com/cj-mills/cjm-byte-track/blob/main/cjm_byte_track/basetrack.py#L106){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseTrack.mark_lost
#
# >      BaseTrack.mark_lost ()
#
# Marks the track as lost.

# %%
#| echo: false
#| output: asis
show_doc(BaseTrack.mark_removed)
# Out:
# ---
#
# [source](https://github.com/cj-mills/cjm-byte-track/blob/main/cjm_byte_track/basetrack.py#L112){target="_blank" style="float:right; font-size:smaller"}
#
# ### BaseTrack.mark_removed
#
# >      BaseTrack.mark_removed ()
#
# Marks the track as removed.
